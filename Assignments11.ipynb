# %% [markdown]
# # Assingment 11

# %% [markdown]
# Homework 11
#
# • Write 3 programs that take square root of a number N (perform 100 trials) and compare against<br>
# numpy square-root function for error. Analyze the errors and determine the best methods based on<br>
# mean error and standard deviation of error.<br>
# • Naïve method<br>
# • Babylonian method<br>
# • Exponential-log method<br>
